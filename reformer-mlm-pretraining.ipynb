# %% [markdown]
# ## Google Drive

# %%
  from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Install Package

# %%
# !pip install -r "/content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt"
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from -r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 1)) (1.7.1+cu101)
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/f9/54/5ca07ec9569d2f232f3166de5457b63943882f7950ddfcc887732fc7fb23/transformers-4.3.3-py3-none-any.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 4.3MB/s
# Collecting reformer_pytorch==1.1.3
#   Downloading https://files.pythonhosted.org/packages/a5/75/aaf6162bd305b7ee88136425b725df482b6cb812783ce82748bd469ea21a/reformer_pytorch-1.1.3-py3-none-any.whl
# Collecting electra-pytorch
#   Downloading https://files.pythonhosted.org/packages/38/a4/b1484566695354028cfc4d01df520d8590e6fb0791594977f1bfdf275ebb/electra_pytorch-0.1.1-py3-none-any.whl
# Collecting kss
#   Downloading https://files.pythonhosted.org/packages/c9/e2/43ac92280810437a552111db85a0379dfaa5ca8ccd81d27a547e9091e5d5/kss-2.5.0-py3-none-any.whl (68kB)
#      |████████████████████████████████| 71kB 8.8MB/s
# Collecting fairseq==0.9.0
#   Downloading https://files.pythonhosted.org/packages/67/bf/de299e082e7af010d35162cb9a185dc6c17db71624590f2f379aeb2519ff/fairseq-0.9.0.tar.gz (306kB)
#      |████████████████████████████████| 307kB 42.0MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 1)) (3.7.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 1)) (1.19.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 2)) (20.9)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/71/23/2ddc317b2121117bf34dd00f5b0de194158f2a44ee2bf5e47c7166878a97/tokenizers-0.10.1-cp37-cp37m-manylinux2010_x86_64.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 43.9MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 2)) (4.41.1)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 37.1MB/s
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 2)) (3.7.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 2)) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 2)) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 2)) (3.0.12)
# Collecting axial-positional-embedding>=0.1.0
#   Downloading https://files.pythonhosted.org/packages/7a/27/ad886f872b15153905d957a70670efe7521a07c70d324ff224f998e52492/axial_positional_embedding-0.2.1.tar.gz
# Collecting product-key-memory
#   Downloading https://files.pythonhosted.org/packages/31/3b/c1f8977e4b04f047acc7b23c7424d1e2e624ed7031e699a2ac2287af4c1f/product_key_memory-0.1.10.tar.gz
# Collecting local-attention
#   Downloading https://files.pythonhosted.org/packages/a0/86/f1df73868c1c433a9184d94e86cdd970951ecf14d8b556b41302febb9a12/local_attention-1.2.2-py3-none-any.whl
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from electra-pytorch->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 4)) (1.4.1)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from electra-pytorch->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 4)) (0.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.7/dist-packages (from fairseq==0.9.0->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 6)) (1.14.5)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from fairseq==0.9.0->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 6)) (0.29.22)
# Collecting sacrebleu
#   Downloading https://files.pythonhosted.org/packages/3b/7f/4fd83db8570288c3899d8e57666c2841403c15659f3d792a3cb8dc1c6689/sacrebleu-1.5.0-py3-none-any.whl (65kB)
#      |████████████████████████████████| 71kB 8.2MB/s
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 2)) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 2)) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 2)) (3.4.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 2)) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 2)) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 2)) (1.24.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn->electra-pytorch->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 4)) (0.22.2.post1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi->fairseq==0.9.0->-r /content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt (line 6)) (2.20)
# Collecting portalocker
#   Downloading https://files.pythonhosted.org/packages/82/22/e684c9e2e59b561dbe36538852e81849122c666c423448e3a5c99362c228/portalocker-2.2.1-py2.py3-none-any.whl
# Building wheels for collected packages: fairseq, sacremoses, axial-positional-embedding, product-key-memory
#   Building wheel for fairseq (setup.py) ... done
#   Created wheel for fairseq: filename=fairseq-0.9.0-cp37-cp37m-linux_x86_64.whl size=2086058 sha256=73b5d34ca04d96bb89f13dfba33843667c9fbaa5dbc39fb2c827bcf8f125b4a6
#   Stored in directory: /root/.cache/pip/wheels/37/3e/1b/0fa30695dcba41e4b0088067fa40f3328d1e8ee78c22cd4766
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp37-none-any.whl size=893262 sha256=765f26c45301f4a21e34effbb86f6b90fdf43abb5fe96bcc889b30a41caa2953
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
#   Building wheel for axial-positional-embedding (setup.py) ... done
#   Created wheel for axial-positional-embedding: filename=axial_positional_embedding-0.2.1-cp37-none-any.whl size=2905 sha256=490416ca7443e7387a1ad3afc5a9859888d56b14a6ffa438eb4289396ffbe12c
#   Stored in directory: /root/.cache/pip/wheels/cd/f8/93/25b60e319a481e8f324dcb1871aff818eb0c8143ed20b732b4
#   Building wheel for product-key-memory (setup.py) ... done
#   Created wheel for product-key-memory: filename=product_key_memory-0.1.10-cp37-none-any.whl size=3072 sha256=df2e8454835984570a947069ea2fa976774081063c7caf410ae422e5e7c4a048
#   Stored in directory: /root/.cache/pip/wheels/6d/e0/3b/fd3111a4fac652ed014ccfd4757754f006132723985e229419
# Successfully built fairseq sacremoses axial-positional-embedding product-key-memory
# ERROR: electra-pytorch 0.1.1 has requirement transformers==3.0.2, but you'll have transformers 4.3.3 which is incompatible.
# Installing collected packages: tokenizers, sacremoses, transformers, axial-positional-embedding, product-key-memory, local-attention, reformer-pytorch, electra-pytorch, kss, portalocker, sacrebleu, fairseq
# Successfully installed axial-positional-embedding-0.2.1 electra-pytorch-0.1.1 fairseq-0.9.0 kss-2.5.0 local-attention-1.2.2 portalocker-2.2.1 product-key-memory-0.1.10 reformer-pytorch-1.1.3 sacrebleu-1.5.0 sacremoses-0.0.43 tokenizers-0.10.1 transformers-4.3.3

# %% [markdown]
# ## Pretraining

# %%
# !python3 "/content/drive/My Drive/Colab Notebooks/reformer-language-model/pretrain/mlm-model-small.py"
# Out:
# 100% 1/1 [00:06<00:00,  6.79s/it]
# Epoch-47 Iterator: 100% 4057/4057 [1:00:56<00:00,  1.11it/s, 2021-03-03 16:03:05.825881 | Train Loss: 1.8844869136810303 | Steps: 194736]
# Evaluating: 100% 451/451 [08:40<00:00,  1.15s/it]
# Epoch-48 Iterator: 100% 4057/4057 [3:26:38<00:00,  3.06s/it, 2021-03-03 19:38:24.048713 | Train Loss: 1.7525060176849365 | Steps: 198793]
# Evaluating: 100% 451/451 [08:37<00:00,  1.15s/it]
# Epoch-49 Iterator: 100% 4057/4057 [3:26:00<00:00,  3.05s/it, 2021-03-03 23:13:02.282313 | Train Loss: 1.6674014329910278 | Steps: 202850]
# Evaluating: 100% 451/451 [08:41<00:00,  1.16s/it]
# Epoch-50 Iterator: 100% 4057/4057 [3:26:09<00:00,  3.05s/it, 2021-03-04 02:47:52.954471 | Train Loss: 1.7718971967697144 | Steps: 206907]
# Evaluating: 100% 451/451 [08:46<00:00,  1.17s/it]
# Epoch-51 Iterator: 100% 4057/4057 [3:26:58<00:00,  3.06s/it, 2021-03-04 06:23:38.522839 | Train Loss: 1.9086049795150757 | Steps: 210964]
# Evaluating: 100% 451/451 [08:44<00:00,  1.16s/it]
# Epoch-52 Iterator: 100% 4057/4057 [3:26:58<00:00,  3.06s/it, 2021-03-04 09:59:21.016978 | Train Loss: 1.6524523496627808 | Steps: 215021]
# Evaluating: 100% 451/451 [08:43<00:00,  1.16s/it]
# Epoch-53 Iterator:  26% 1061/4057 [54:09<2:32:42,  3.06s/it, 2021-03-04 11:02:14.015869 | Train Loss: 1.8916271924972534 | Steps: 216082]
