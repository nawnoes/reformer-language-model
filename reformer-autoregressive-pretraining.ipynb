# %% [markdown]
# ## Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Install Package

# %%
# !pip install -r "/content/drive/My Drive/Colab Notebooks/reformer-language-model/requirements.txt"
# Out:
# ...
#      |████████████████████████████████| 1.8MB 13.1MB/s
# ...
#      |████████████████████████████████| 71kB 11.0MB/s
# ...
#      |████████████████████████████████| 307kB 52.9MB/s
# ...
#      |████████████████████████████████| 890kB 55.4MB/s
# ...
#      |████████████████████████████████| 2.9MB 54.8MB/s
# ...
#      |████████████████████████████████| 71kB 9.3MB/s
# ...
#   Created wheel for fairseq: filename=fairseq-0.9.0-cp36-cp36m-linux_x86_64.whl size=2064559 sha256=25fe3df5e1c006529954a7d41a3c74dadc48964585c5add8f61d790ad14b4937
#   Stored in directory: /root/.cache/pip/wheels/37/3e/1b/0fa30695dcba41e4b0088067fa40f3328d1e8ee78c22cd4766
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=e311d269ad2e88df27bff6f991d9d5ceacc11ad590c7737c7f7773644d161cd3
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# ...

# %% [markdown]
# ## Pretraining

# %%
# !python3 "/content/drive/My Drive/Colab Notebooks/reformer-language-model/pretrain/autoregressive-model.py"
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Epoch-11 Iterator:  36% 2882/7941 [2:12:27<3:51:11,  2.74s/it, 2021-02-06 13:20:51.114875 | Train Loss: 2.927656888961792 | Steps: 89854]
# Epoch-11 Iterator:  36% 2883/7941 [2:12:27<3:51:01,  2.74s/it, 2021-02-06 13:20:51.114875 | Train Loss: 2.927656888961792 | Steps: 89854]
# Epoch-11 Iterator:  36% 2883/7941 [2:12:29<3:51:01,  2.74s/it, 2021-02-06 13:20:53.859510 | Train Loss: 2.677527666091919 | Steps: 89855]
# Epoch-11 Iterator:  36% 2884/7941 [2:12:30<3:51:05,  2.74s/it, 2021-02-06 13:20:53.859510 | Train Loss: 2.677527666091919 | Steps: 89855]
# Epoch-11 Iterator:  36% 2884/7941 [2:12:32<3:51:05,  2.74s/it, 2021-02-06 13:20:56.575978 | Train Loss: 2.897111177444458 | Steps: 89856]
# Epoch-11 Iterator:  36% 2885/7941 [2:12:32<3:50:19,  2.73s/it, 2021-02-06 13:20:56.575978 | Train Loss: 2.897111177444458 | Steps: 89856]
# ...
